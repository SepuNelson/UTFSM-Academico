# %% [markdown]
# <hr style="height:2px;border:none"/>
# <h1 align='center'> INF-280 Estadística Computacional II-2022 </h1>
#
# <H3 align='center'> Tema 8 - Test de Hipótesis  </H3>
#
# \
#
#
# Nombre del equipo:
#
# Integrantes:
#
#
# *   Nombre Integrante 1 - ROL - [video](https://youtu.be/A6O67uLJfcQ)
# *   Nombre Integrante 2 - ROL - [video](https://youtu.be/A6O67uLJfcQ)
# *   Nombre Integrante 3 - ROL - [video](https://youtu.be/A6O67uLJfcQ)
#
#
# *Recuerden que si su equipo se llama "El ritmo no perdona", entonces el nombre del archivo a subir debe ser T8_El_ritmo_no_perdona.ipynb*
#
#
# ### **Formalidades**
# * Es posible utilizar apuntes, libros, papers, ejemplos y cualquier otro material que desee de internet, pero debe ser usted quien desarrolle los ejercicios y comente los resultados en el Notebook que entregará.
# * Se permite el uso de las librerías: pandas, numpy, matplotlib y seaborn. Si desea utilizar otra librería debe indicar cómo instalarla.
# * Se debe trabajar en grupos de **dos o tres personas**, las cuales deberán estar inscritas a través de __[Aula](https://aula.usm.cl/)__.
# * Además del Notebook, deberán entregar un video explicando lo que hizo, paso a paso, como en los ejemplos entregados en AULA. Este vídeo es **individual**, es decir, cada integrante debe hacerlo por separado (debiendo utilizar el mismo Jupyter Notebook). El video puede ser subido a una plataforma externa como Youtube, Google Drive, ó Dropbox. El **link a compartir** (*visible para cualquier usuario con el link*) debe ir dentro del Notebook.
# * La nota de esta actividad es grupal.
#
#
# <hr style="height:2px;border:none"/>
#
# ### **Entrega**
# * **Formato**: Se debe realizar una **única** entrega por grupo (un representate del grupo) a través de  __[**Aula**](https://aula.usm.cl/)__.
# * **Archivo**: El nombre del archivo a subir debe ser **T8_Nombre_Del_Equipo.ipynb**, por ejemplo, si su equipo se llama "El ritmo no perdona", entonces el nombre del archivo debe ser **T8_El_ritmo_no_perdona.ipynb**
# * **Archivo**: Sus respuestas deben ser entregadas en forma de Jupyter Notebook, incluyendo **todos links** a los vídeos explicativos, uno por cada integrante.
#     * **Vídeo**: Debe grabar la pantalla (Jupyter Notebok) donde se realiza la explicación de la actividad, con una duración máxima de 25 minutos.
# * **Fecha límite**: Martes 6 de Diciembre a las 23:59
#
# <hr style="height:2px;border:none"/>
#
# ### **Descuentos**
#
# * Se descontarán 5 puntos si el nombre del archivo subido no sigue el formato señalado.
# * Se descontarán 10 puntos por cada hora de atraso en la entrega.
# * Todos los gráficos que realicen deben contener los nombres de las variables en los ejes. Se descontarán 3 puntos por cada nombre faltante.
#
# <hr style="height:2px;border:none"/>

# %% [markdown]
# <table align='left'>
# <tr>
# <td><img src='https://comunicacion.uaa.mx/revista/wp-content/uploads/2019/01/discurso-620x350.png' width='650'/> </td>
# </tr>
# </table>

# %% [markdown]
# ## Contexto

# %% [markdown]
# La Universidad de Harvard ha recopilado una serie de discursos para medir el nivel de populismo en los discursos de 241 jefes ejecutivos (presidentes y primeros ministros) de 74 países de todos los continentes. El conjunto de datos cubre 324 mandatos gubernamentales e incluye 1240 discursos, en su mayoría entre 2000 y 2022.
#
# El dataset `gpd_v2_20220427.csv` está compuesto por los siguientes atriibutos:
#
# 1.   `merging_variable`: name of the .txt file in the folder with Speeches with the speech that matches that coder’s score.
# 2.   `Country`
# 3.   `Leader`: name of president or prime minister.
# 4.   `lr`: categorical indicator with -1 = left; 0 = center; 1 = right.
# 5.   `president`: binary. 1 if the leader is a president, 0 if a prime minister.
# 6.   `term`: leader term in office, ordinal.
# 8.   `startofterm`: date of start of respective term
# 9.   `yearbegin`: year of beginning of term.
# 10.   `endofterm`: date of end of respective term.
# 11.   `yearend`: year of ending of respective term.
# 12.   `speechtype`: type of speech: international, campaign, ribbon-cutting, famous.
# 13.   `speechnum`: number of that speech for that leader-term.
# 14.   `codernum`: coder identifier for that speech-leader.
# 15.   `rubricgrade`: grade of that speech by that coder on the 0-2 populism scale.
# 16.   `averagerubric`: average populism grade for that speech. Arithmetic average across all coders for that speech.
# 17.    `totalaverage`: average populism grade for that leader-term. Arithmetic mean for all speeches by all coders for that leader-term
# 18.    `wb_region`: World Bank global region classification.

# %% [markdown]
# # Librerías

# %%
import pandas as pd
import numpy as np
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Datos

# %%
data = pd.read_csv("gpd_v2_20220427.csv")
data
# Out:
#                             merging_variable    country          leader  \
# 0             Albania_Berisha_Campaign_2.txt    Albania    Sali Berisha
# 1             Albania_Berisha_Campaign_2.txt    Albania    Sali Berisha
# 2             Albania_Berisha_Campaign_2.txt    Albania    Sali Berisha
# 3             Albania_Berisha_Campaign_2.txt    Albania    Sali Berisha
# 4               Albania_Berisha_Ribbon_2.txt    Albania    Sali Berisha
# ...                                      ...        ...             ...
# 4955  Australia_Morrison_International_1.txt  Australia  Scott Morrison
# 4956         Australia_Morrison_Ribbon_1.txt  Australia  Scott Morrison
# 4957         Australia_Morrison_Ribbon_1.txt  Australia  Scott Morrison
# 4958         Australia_Morrison_Ribbon_1.txt  Australia  Scott Morrison
# 4959         Australia_Morrison_Ribbon_1.txt  Australia  Scott Morrison
#
#                             party   lr  president  term startofterm  \
# 0     Democratic Party of Albania  0.0          0     2  2009-06-28
# 1     Democratic Party of Albania  0.0          0     2  2009-06-28
# 2     Democratic Party of Albania  0.0          0     2  2009-06-28
# 3     Democratic Party of Albania  0.0          0     2  2009-06-28
# 4     Democratic Party of Albania  0.0          0     2  2009-06-28
# ...                           ...  ...        ...   ...         ...
# 4955   Liberal Party of Australia  NaN          0     1  2018-04-24
# 4956   Liberal Party of Australia  NaN          0     1  2018-04-24
# 4957   Liberal Party of Australia  NaN          0     1  2018-04-24
# 4958   Liberal Party of Australia  NaN          0     1  2018-04-24
# 4959   Liberal Party of Australia  NaN          0     1  2018-04-24
#
#       yearbegin   endofterm  yearend      speechtype  speechnum  codernum  \
# 0          2009  2013-06-23     2013        Campaign          1         1
# 1          2009  2013-06-23     2013        Campaign          1         2
# 2          2009  2013-06-23     2013        Campaign          1         3
# 3          2009  2013-06-23     2013        Campaign          1         4
# 4          2009  2013-06-23     2013  Ribbon cutting          2         1
# ...         ...         ...      ...             ...        ...       ...
# 4955       2018     present  present   International          3         4
# 4956       2018     present  present  Ribbon cutting          4         1
# 4957       2018     present  present  Ribbon cutting          4         2
# 4958       2018     present  present  Ribbon cutting          4         3
# 4959       2018     present  present  Ribbon cutting          4         4
#
#       rubricgrade  averagerubric  totalaverage              wb_region  \
# 0             0.0            0.5       0.12500  Europe & Central Asia
# 1             1.0            0.5       0.12500  Europe & Central Asia
# 2             NaN            0.5       0.12500  Europe & Central Asia
# 3             NaN            0.5       0.12500  Europe & Central Asia
# 4             0.0            0.0       0.12500  Europe & Central Asia
# ...           ...            ...           ...                    ...
# 4955          NaN            0.0       0.15625    East Asia & Pacific
# 4956          0.0            0.0       0.15625    East Asia & Pacific
# 4957          0.0            0.0       0.15625    East Asia & Pacific
# 4958          NaN            0.0       0.15625    East Asia & Pacific
# 4959          NaN            0.0       0.15625    East Asia & Pacific
#
#                           region
# 0     Central and Eastern Europe
# 1     Central and Eastern Europe
# 2     Central and Eastern Europe
# 3     Central and Eastern Europe
# 4     Central and Eastern Europe
# ...                          ...
# 4955                         NaN
# 4956                         NaN
# 4957                         NaN
# 4958                         NaN
# 4959                         NaN
#
# [4960 rows x 19 columns]

# %% [markdown]
# # Preguntas

# %% [markdown]
# ---
#
# **Importante** para las siguientes preguntas:
# * Indique explicitamente **los supuestos** que consideraron.
# * Indique explicitamente **$H_0$** y **$H_1$**.
# * Indique explicitamente el valor del **Estadístico de Contraste**.
# * Indique explicitamente la **Región Crítica**.
# * Indique explicitamente si **se acepta $H_0$** o **se rechaza $H_0$**.
#
# ---
#
# 1. Considerando solo los discursos realizados en  `region=Latin America & Caribbean` y `region=Western Europe` desde el año 2000 en adelante y solamente aquellos realizados en campaña (`speechtype = Campaign`).
#
# > a) Diseñe un contraste que permita evaluar la hipótesis de que "*los discursos realizados por presidentes de izquierda (`lr = -1`) son igual de populistas (`rubricgrade`) en ambas regiones*". Diseñe su contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%. **(10 pts)**
#
# > b) Diseñe un contraste que permita evaluar la hipótesis de que "*los discursos realizados por presidentes de centro (`lr = 0`) son igual de populistas (`rubricgrade`) en ambas regiones*". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%. **(10 pts)**
#
# > c) Diseñe un contraste que permita evaluar la hipótesis de que "*los discursos realizados por presidentes de derecha (`lr = 1`) son igual de populistas (`rubricgrade`) en ambas regiones*". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%. **(10 pts)**
#
# 2. Considerando solo los discursos realizados en Chile desde el año 2000 en adelante. Diseñe un contraste que permita evaluar la hipótesis de que "*los discursos realizados por presidentes de izquierda (`lr = -1`) son **más populistas** (utilice `rubricgrade`) que los discursos realizados por presidentes de derecha (`lr = -1`)*". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%.  **(10 pts)**
#
# 3. En Chile, Michelle Bachelet y Sebastián Piñera han sido dos veces presidente de la república. Por esto, podría resultar interesante determinar si sus niveles de populismo (utilice `rubricgrade`) en sus discursos cambiaron en algo durante sus dos mandatos.
#
# > a) Diseñe un contraste que permita evaluar la hipótesis de que "*los discursos de "Bachelet 1" son **igual o más populistas** que los discursos de "Bachelet 2"* ". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%. **(15 pts)**
#
# > b) Diseñe un contraste que permita evaluar la hipótesis de que "*los discursos de "Piñera 1" son **igual o más populistas** que los discursos de "Piñera 2"* ". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%. **(15 pts)**
#
# 4. En los últimos 20 años Argentina ha aumentado su nivel de pobreza, donde más del 25% de la población del país se encuentra en esta situación.
#
# > a) Diseñe un contraste que permita evaluar la hipótesis de que "*el nivel de populismo (utilice `rubricgrade`) en los discursos de presidentes argentinos es mayor a 0.5*". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%. **(10 pts)**
#
# > b) Diseñe un contraste que permita evaluar la hipótesis de que "*los discursos realizados por presidentes argentinos son más populistas que los discursos realizados por el resto de países de `region=Latin America & Caribbean`*". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%  **(10 pts)**
#
#
#
# ---
#
#
# *Análisis de discursos*
#
# La función **`analizar`** analiza un discurso y retorna un número entre 1 y 3, donde:
#
# * 1 indica que el discurso tiene una connotación negativa.
# * 2 indica que el discruso tiene una connotación neutra.
# * 3 indica que el discurso tiene una connotación positiva.
#
# ---
#
# 5. Diseñe un contraste que permita evaluar la hipótesis de que "*la proporción de discursos positivos realizados por presidentes Chilenos es mayor que la proporción de discursos positivos realizados en `region=Latin America & Caribbean`*". Diseñe un contraste de manera que la probabilidad de aceptar incorrectamente esta conjetura sea menor al 5%. Además, indique el p-valor. **Importante: No incluya a brasil** **(10 pts)**
#
# ---
# **Pregunta Extra** (10 pts)
#
# Responda a la pregunta 5), pero considerando un país elegido por usted y el tipo de discurso que desea analizar.

# %% [markdown]
# # Respuestas

# %% [markdown]
# ## Pregunta 1:

# %% [markdown]
# El DataFrame de los los discursos realizados en Latin America & Caribbean y Western Europe desde el año 2000 en adelante y solamente aquellos realizados en campaña, queda finalmente de la siguiente forma:

# %%
## DataFrame de los los discursos realizados en region=Latin America & Caribbean y region=Western Europe desde el año 2000 en adelante y solamente aquellos realizados en campaña (speechtype = Campaign).
dataLAC = data[data.region == 'Latin America & Caribbean']
data2000 = dataLAC[dataLAC.yearbegin.isin([2000,2021])]
data_lac = data2000[data2000.speechtype == 'Campaign']

dataWE = data[data.region == 'Western Europe']
data2000 = dataWE[dataWE.yearbegin.isin([2000,2021])]
data_we = data2000[data2000.speechtype == 'Campaign']

data_p1 = pd.concat([data_lac, data_we])

print(data_p1['rubricgrade'].sum())

data_p1
# Out:
# 2.5
#                                  merging_variable             country  \
# 784                    Chile_Lagos_Campaign_1.txt               Chile
# 785                    Chile_Lagos_Campaign_1.txt               Chile
# 786                    Chile_Lagos_Campaign_1.txt               Chile
# 787                    Chile_Lagos_Campaign_1.txt               Chile
# 1212      Dominican Republic_Mejia_Campaign_1.txt  Dominican Republic
# 1213      Dominican Republic_Mejia_Campaign_1.txt  Dominican Republic
# 1214      Dominican Republic_Mejia_Campaign_1.txt  Dominican Republic
# 1215      Dominican Republic_Mejia_Campaign_1.txt  Dominican Republic
# 312               Austria_Schussel_Campaign_1.txt             Austria
# 313               Austria_Schussel_Campaign_1.txt             Austria
# 314               Austria_Schussel_Campaign_1.txt             Austria
# 315               Austria_Schussel_Campaign_1.txt             Austria
# 3640                   Spain_Aznar_Campaign_2.txt               Spain
# 3641                   Spain_Aznar_Campaign_2.txt               Spain
# 3642                   Spain_Aznar_Campaign_2.txt               Spain
# 3643                   Spain_Aznar_Campaign_2.txt               Spain
# 3776  Switzerland_Parmelin_Blocher_Campaign_1.txt         Switzerland
# 3777  Switzerland_Parmelin_Blocher_Campaign_1.txt         Switzerland
# 3778  Switzerland_Parmelin_Blocher_Campaign_1.txt         Switzerland
# 3779  Switzerland_Parmelin_Blocher_Campaign_1.txt         Switzerland
#
#                               leader                             party   lr  \
# 784                    Ricardo Lagos               Party for Democracy -1.0
# 785                    Ricardo Lagos               Party for Democracy -1.0
# 786                    Ricardo Lagos               Party for Democracy -1.0
# 787                    Ricardo Lagos               Party for Democracy -1.0
# 1212                  Hipolito Mejia     Dominican Revolutionary Party  0.0
# 1213                  Hipolito Mejia     Dominican Revolutionary Party  0.0
# 1214                  Hipolito Mejia     Dominican Revolutionary Party  0.0
# 1215                  Hipolito Mejia     Dominican Revolutionary Party  0.0
# 312                Wolfgang Schussel           Austrian People's Party  1.0
# 313                Wolfgang Schussel           Austrian People's Party  1.0
# 314                Wolfgang Schussel           Austrian People's Party  1.0
# 315                Wolfgang Schussel           Austrian People's Party  1.0
# 3640                Jose Maria Aznar  Spanish Socialist Workers' Party -1.0
# 3641                Jose Maria Aznar  Spanish Socialist Workers' Party -1.0
# 3642                Jose Maria Aznar  Spanish Socialist Workers' Party -1.0
# 3643                Jose Maria Aznar  Spanish Socialist Workers' Party -1.0
# 3776  Guy Parmelin/Christoph Blocher              Swiss People's Party  1.0
# 3777  Guy Parmelin/Christoph Blocher              Swiss People's Party  1.0
# 3778  Guy Parmelin/Christoph Blocher              Swiss People's Party  1.0
# 3779  Guy Parmelin/Christoph Blocher              Swiss People's Party  1.0
#
#       president  term startofterm  yearbegin   endofterm yearend speechtype  \
# 784           1     1  2000-03-11       2000  2006-03-11    2006   Campaign
# 785           1     1  2000-03-11       2000  2006-03-11    2006   Campaign
# 786           1     1  2000-03-11       2000  2006-03-11    2006   Campaign
# 787           1     1  2000-03-11       2000  2006-03-11    2006   Campaign
# 1212          1     1  2000-08-16       2000  2004-08-16    2004   Campaign
# 1213          1     1  2000-08-16       2000  2004-08-16    2004   Campaign
# 1214          1     1  2000-08-16       2000  2004-08-16    2004   Campaign
# 1215          1     1  2000-08-16       2000  2004-08-16    2004   Campaign
# 312           0     1  2000-02-04       2000  2003-02-28    2003   Campaign
# 313           0     1  2000-02-04       2000  2003-02-28    2003   Campaign
# 314           0     1  2000-02-04       2000  2003-02-28    2003   Campaign
# 315           0     1  2000-02-04       2000  2003-02-28    2003   Campaign
# 3640          0     2  2000-05-05       2000  2004-04-16    2004   Campaign
# 3641          0     2  2000-05-05       2000  2004-04-16    2004   Campaign
# 3642          0     2  2000-05-05       2000  2004-04-16    2004   Campaign
# 3643          0     2  2000-05-05       2000  2004-04-16    2004   Campaign
# 3776          1     1  2021-01-01       2021  2021-12-31    2021   Campaign
# 3777          1     1  2021-01-01       2021  2021-12-31    2021   Campaign
# 3778          1     1  2021-01-01       2021  2021-12-31    2021   Campaign
# 3779          1     1  2021-01-01       2021  2021-12-31    2021   Campaign
#
#       speechnum  codernum  rubricgrade  averagerubric  totalaverage  \
# 784           1         1          0.0           0.00      0.083333
# 785           1         2          0.0           0.00      0.083333
# 786           1         3          NaN           0.00      0.083333
# 787           1         4          NaN           0.00      0.083333
# 1212          1         1          0.1           0.05      0.075000
# 1213          1         2          0.0           0.05      0.075000
# 1214          1         3          NaN           0.05      0.075000
# 1215          1         4          NaN           0.05      0.075000
# 312           1         1          0.5           0.40      0.133333
# 313           1         2          0.3           0.40      0.133333
# 314           1         3          NaN           0.40      0.133333
# 315           1         4          NaN           0.40      0.133333
# 3640          1         1          0.0           0.00      0.050000
# 3641          1         2          0.0           0.00      0.050000
# 3642          1         3          NaN           0.00      0.050000
# 3643          1         4          NaN           0.00      0.050000
# 3776          1         1          1.6           1.60      0.566667
# 3777          1         2          NaN           1.60      0.566667
# 3778          1         3          NaN           1.60      0.566667
# 3779          1         4          NaN           1.60      0.566667
#
#                       wb_region                     region
# 784   Latin America & Caribbean  Latin America & Caribbean
# 785   Latin America & Caribbean  Latin America & Caribbean
# 786   Latin America & Caribbean  Latin America & Caribbean
# 787   Latin America & Caribbean  Latin America & Caribbean
# 1212  Latin America & Caribbean  Latin America & Caribbean
# 1213  Latin America & Caribbean  Latin America & Caribbean
# 1214  Latin America & Caribbean  Latin America & Caribbean
# 1215  Latin America & Caribbean  Latin America & Caribbean
# 312       Europe & Central Asia             Western Europe
# 313       Europe & Central Asia             Western Europe
# 314       Europe & Central Asia             Western Europe
# 315       Europe & Central Asia             Western Europe
# 3640      Europe & Central Asia             Western Europe
# 3641      Europe & Central Asia             Western Europe
# 3642      Europe & Central Asia             Western Europe
# 3643      Europe & Central Asia             Western Europe
# 3776      Europe & Central Asia             Western Europe
# 3777      Europe & Central Asia             Western Europe
# 3778      Europe & Central Asia             Western Europe
# 3779      Europe & Central Asia             Western Europe

# %% [markdown]
# Considerando solo los datos entregados por el enunciado, nos queda una tabla de 20 filas. En la cual se evaluaran las siguientes Hipotesis:

# %% [markdown]
# ### a)
# Variable Aleatoria X: presidentes de izquierda.
# Parametro: suma total de la escala de populismo
# \begin{align}
# STP =\sum_{i=1}^n r
# \end{align}
# Siendo n la cantidad de presidentes de izquierda que cumplen los requisitos del enunciado y r el Rubricgrade del presidente.
# H<sub>0</sub> : Los discursos realizados por presidentes de izquierda son igual de populistas en ambas regiones T:  (total_lac = total_we).
# H<sub>1</sub> : Los discursos realizados por presidentes de izquierda NO son igual de populistas en ambas regiones.

# %%
my_alpha = 

#suma de rubricgrade en LAC de lr = -1.
#hacemos un dataFrame considerando solo los lr=-1.
data_l = data_lac[data_lac.lr == -1]

#Suma de rubricgrade
total_lac = data_l['rubricgrade'].sum()
print(total_lac)
# Out:
# 0.0

# %%
#suma de rubricgrade en WE de lr = -1.
#hacemos un dataFrame considerando solo los lr=-1.
data_l = data_we[data_we.lr == -1]

#Suma de rubricgrade
total_we = data_l['rubricgrade'].sum()
print(total_we)
# Out:
# 0.0

# %% [markdown]
# En el caso de ambas regiones el nivel de populismo de los presidentes de izquierda es nulo.
# Considerando la región crítica como:
# R = (total_lac > total_we) $\cup$ (total_lac < total_we) = ]-$\infty$, 0[   $\cup$   ]0, $\infty$[.
#
# Dado los valores del experimento: se acepta H<sub>0</sub> dado que el populismo de ambos partidos para la region de Latin America & Caribbean es igual, igual a 0.

# %% [markdown]
# ### b)
# Variable Aleatoria X: presidentes de centro.
# Parametro: suma total de la escala de populismo.
# H<sub>0</sub> : Los discursos realizados por presidentes de centro son igual de populistas en ambas regiones.
# H<sub>1</sub> : Los discursos realizados por presidentes de centro NO son igual de populistas en ambas regiones.

# %%
#suma de rubricgrade en LAC de lr = 0.
#hacemos un dataFrame considerando solo los lr=0.
data_c = data_lac[data_lac.lr == 0]

#Suma de rubricgrade
total_lac = data_c['rubricgrade'].sum()
print(total_lac)
# Out:
# 0.1

# %%
#suma de rubricgrade en WE de lr = 0.
#hacemos un dataFrame considerando solo los lr=0.
data_c = data_we[data_we.lr == 0]

#Suma de rubricgrade
total_we = data_c['rubricgrade'].sum()
print(total_we)
# Out:
# 0.0

# %% [markdown]
# ### c)
# Variable Aleatoria X: presidentes de derecha.
# Parametro: suma total de la escala de populismo.
# H<sub>0</sub> : Los discursos realizados por presidentes de derecha son igual de populistas en ambas regiones.
# H<sub>1</sub> : Los discursos realizados por presidentes de derecha NO son igual de populistas en ambas regiones.

# %%
#suma de rubricgrade en LAC de lr = 1.
#hacemos un dataFrame considerando solo los lr=1.
data_r = data_lac[data_lac.lr == 1]

#Suma de rubricgrade
total_lac = data_r['rubricgrade'].sum()
print(total_lac)
data_r
# Out:
# 0.0
# Empty DataFrame
# Columns: [merging_variable, country, leader, party, lr, president, term, startofterm, yearbegin, endofterm, yearend, speechtype, speechnum, codernum, rubricgrade, averagerubric, totalaverage, wb_region, region]
# Index: []

# %%
#suma de rubricgrade en WE de lr = 1.
#hacemos un dataFrame considerando solo los lr=1.
data_r = data_we[data_we.lr == 1]

#Suma de rubricgrade
total_we = data_r['rubricgrade'].sum()
print(round(total_we, 2))
# Out:
# 2.4

# %% [markdown]
# ## Pregunta 4:

# %%
#H0: mu1 = mu0 (mu1 desconocida, m0 valor fijo)
def contrate_1media(n1,media1,std1,mu0,error_tipo1,alternativa='1>0'):
  region_critica = []
  gl = n1-1
  std_error = np.sqrt(std1**2/n1)
  T0 = (media1-mu0)/std_error#estadistico bajo H0
  if (alternativa=='1>0'):
    region_critica.append(pd.Interval(left=t.ppf(1-error_tipo1,df=gl), right=np.inf,closed='neither'))
    p_value = 1-t.cdf(T0,df=gl)
  elif (alternativa=='1<0'):
    region_critica.append(pd.Interval(left=-np.inf, right=t.ppf(error_tipo1,df=gl),closed='neither'))
    p_value = t.cdf(T0,df=gl)
  else:#dos colas
    region_critica.append(pd.Interval(left=-np.inf,right=t.ppf(error_tipo1/2,df=gl),closed='neither'))
    region_critica.append(pd.Interval(left=t.ppf(1-error_tipo1/2,df=gl),right=np.inf,closed='neither'))
    p_value = 2*min(1-t.cdf(T0,df=gl),t.cdf(T0,df=gl))
  return T0, region_critica, p_value

# %%
#Sacar datos de Argentina
data_argentina = data[data["country"] == "Argentina"]

a = 0.05
mu = 0.5
data1 = []

datos = ["rubricgrade"]
for idx,datos in enumerate(datos):
    valores = data.loc[data[datos] == "Argentina",datos].dropna()
    Promedio = valores.values.mean()
    std = valores.values.std()
    Largo = len(valores)

    estadistico, cr, p_value = contrate_1media(Largo, Promedio, std, mu, a, "<=")
    data1.append([datos, estadistico, cr, p_value])

df1 = pd.DataFrame(data1, columns=["Datos", "Estadístico", "Intervalo crítico", "p-value"])
display(df1)

# %% [markdown]
# ## Pregunta 5:

# %% [markdown]
# # Disclaimer

# %% [markdown]
# Los datos aquí utilizados fueron obtenidos usando la metodología detallada en [1] y por lo tanto no necesariamente reflejan la opinión de los profesores o ayudantes de este curso. Cualquier alusión a personas o países es meramente circustancial y tiene sólo fines pedagógicos. Todo público puede acceder a los datos en [2]
#
# [1] Hawkins, K. A., Aguilar, R., Silva, B. C., Jenne, E. K., Kocijan, B., & Kaltwasser, C. R. (2019, June). Measuring populist discourse: The global populism database. In EPSA Annual Conference in Belfast, UK, June (pp. 20-22).
#
# [2] Hawkins, Kirk A.; Aguilar, Rosario; Castanho Silva, Bruno; Jenne, Erin K.; Kocijan, Bojana; Rovira Kaltwasser, Cristóbal, 2019, "Global Populism Database", https://doi.org/10.7910/DVN/LFTQEZ, Harvard Dataverse, V2
